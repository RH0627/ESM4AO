# %%
from cleanlab.filter import find_label_issues
from sklearn.linear_model import LogisticRegression
from sklearn import preprocessing
from sklearn.model_selection import cross_val_predict
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import pandas as pd
import numpy as np
import os
os.chdir('C:/Users/RH/A_whole_try_prog/ESM320_clean/data')

# %%
df = pd.read_csv("C:/Users/RH/A_whole_try_prog/ESM320_clean/data/ESM_dimension_320.csv")
row_to_delete = 1392
df = df[:row_to_delete+1]
df_c = df.copy()
df['label'] = preprocessing.LabelEncoder().fit_transform(df["label"])
df['label'] = df['label'].astype('category')

## Split data for evaluation
df.reset_index(drop=True, inplace=True)

# %%
# Train model on noisy labels.
train_data = df.drop(['No', 'Sequence', 'label'], axis=1)
train_labels = df['label']

# %%
# Get predicted probabilities through cross validation.
model = LogisticRegression(penalty='l2',max_iter=10000)
pred_probs = cross_val_predict(model, train_data, train_labels, method='predict_proba')

# Returns list of indices of label issues, sorted by self_confidence.
issue_idx = find_label_issues(train_labels, pred_probs, return_indices_ranked_by='self_confidence')
# Filter original data to show students with grade issues.
issue_stud_id = df.iloc[issue_idx].No.values.tolist()
issues_df = df_c[df_c['No'].isin(issue_stud_id)]
issues_df.sort_values(by="No", key=lambda column: column.map(lambda e: issue_stud_id.index(e)), inplace=True)
# Show a few good examples.
issues_df.head()
# Out:
# C:\Users\RH\AppData\Local\Temp\ipykernel_4472\428587186.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   issues_df.sort_values(by="No", key=lambda column: column.map(lambda e: issue_stud_id.index(e)), inplace=True)
#       No        Sequence         0         1         2         3         4  \
# 846  846             PMH  0.055671 -0.203267  0.209244  0.299846 -0.025067
# 910  910            EHNY  0.063344 -0.388523  0.330472  0.215353 -0.009694
# 750  750             TWY  0.105042 -0.137700  0.193816  0.355645  0.077005
# 875  875  LAGKPQQEHSGEHQ  0.085311 -0.387707  0.300029  0.140690 -0.060954
# 882  882        VALGVPHH  0.022685 -0.281447  0.349300  0.042933 -0.067725
#
#             5         6         7  ...       311       312       313  \
# 846 -0.238533 -0.331110 -0.281764  ... -0.131610 -0.011503  0.283627
# 910 -0.197672 -0.136367 -0.082993  ... -0.074203  0.147795  0.022309
# 750 -0.154625 -0.331690 -0.267747  ...  0.028846  0.032943 -0.051368
# 875 -0.072838 -0.113678  0.001116  ... -0.131190  0.078416  0.161138
# 882 -0.219354 -0.292148 -0.162812  ... -0.054921  0.161481 -0.005459
#
#           314       315       316       317       318       319  label
# 846  0.057359  0.254332  0.149765  0.033910  0.229669  0.075105      0
# 910  0.094377  0.113881 -0.138335  0.053564  0.156247 -0.116531      0
# 750  0.167843 -0.012312  0.108793  0.091843  0.283302 -0.083271      0
# 875 -0.007763  0.118178 -0.021098  0.128253 -0.097965 -0.220562      0
# 882 -0.022633  0.065071  0.029935  0.202144  0.168429 -0.128003      0
#
# [5 rows x 323 columns]

# %%
issues_df.head(-1)
# Out:
#       No        Sequence         0         1         2         3         4  \
# 846  846             PMH  0.055671 -0.203267  0.209244  0.299846 -0.025067
# 910  910            EHNY  0.063344 -0.388523  0.330472  0.215353 -0.009694
# 750  750             TWY  0.105042 -0.137700  0.193816  0.355645  0.077005
# 875  875  LAGKPQQEHSGEHQ  0.085311 -0.387707  0.300029  0.140690 -0.060954
# 882  882        VALGVPHH  0.022685 -0.281447  0.349300  0.042933 -0.067725
# ..   ...             ...       ...       ...       ...       ...       ...
# 372  372         TIIPLPV  0.086861 -0.293285  0.317551  0.157457  0.211293
# 380  380    AADNANELFPPN  0.171790 -0.207952  0.288209  0.007952  0.090900
# 460  460          RDMPIQ  0.174713 -0.313125  0.329342  0.244696 -0.079321
# 489  489    STMMEERRMKVY  0.110182 -0.157915  0.317191  0.368001  0.036657
# 315  315            VCSV -0.015157 -0.174702  0.338508  0.100938 -0.106761
#
#             5         6         7  ...       311       312       313  \
# 846 -0.238533 -0.331110 -0.281764  ... -0.131610 -0.011503  0.283627
# 910 -0.197672 -0.136367 -0.082993  ... -0.074203  0.147795  0.022309
# 750 -0.154625 -0.331690 -0.267747  ...  0.028846  0.032943 -0.051368
# 875 -0.072838 -0.113678  0.001116  ... -0.131190  0.078416  0.161138
# 882 -0.219354 -0.292148 -0.162812  ... -0.054921  0.161481 -0.005459
# ..        ...       ...       ...  ...       ...       ...       ...
# 372 -0.133326 -0.141225 -0.141756  ...  0.027203  0.195927  0.020110
# 380 -0.027688 -0.041574 -0.017348  ...  0.099067  0.217530 -0.042080
# 460 -0.158185 -0.209304 -0.008609  ...  0.014621  0.212051  0.082750
# 489 -0.392751 -0.203407 -0.113982  ...  0.023136 -0.005691  0.184087
# 315 -0.137815 -0.310319 -0.243005  ... -0.170006  0.228220  0.137555
#
#           314       315       316       317       318       319  label
# 846  0.057359  0.254332  0.149765  0.033910  0.229669  0.075105      0
# 910  0.094377  0.113881 -0.138335  0.053564  0.156247 -0.116531      0
# 750  0.167843 -0.012312  0.108793  0.091843  0.283302 -0.083271      0
# 875 -0.007763  0.118178 -0.021098  0.128253 -0.097965 -0.220562      0
# 882 -0.022633  0.065071  0.029935  0.202144  0.168429 -0.128003      0
# ..        ...       ...       ...       ...       ...       ...    ...
# 372  0.182890  0.160901  0.235002  0.031931  0.281660  0.111442      1
# 380  0.066354  0.009414 -0.041262  0.184125  0.105614 -0.115968      1
# 460  0.091034  0.130234  0.103649 -0.008375  0.153393  0.104542      1
# 489  0.030794  0.340632  0.052287 -0.048913  0.309693  0.149436      1
# 315 -0.229548  0.282297  0.074717  0.132468  0.386245  0.273665      1
#
# [206 rows x 323 columns]

# %%
list_a = df_c
list_b = issues_df
remove_idx = list_a['No'].isin(list_b['No'])
list_a = list_a[~remove_idx]
print(list_a)
list_a.to_csv("ESM_320_after_clean.csv")
# Out:
#         No  Sequence         0         1         2         3         4  \
# 5        5     FVAGK  0.067417 -0.192779  0.379154  0.160100 -0.009027
# 9        9  LQPGQGQQ  0.164222 -0.528270  0.553837  0.206056 -0.073224
# 10      10    YFYPEL  0.057559 -0.349872  0.287957  0.286531  0.114388
# 11      11     FYPEL  0.064231 -0.422866  0.316937  0.236828  0.095334
# 12      12      YPEL  0.086293 -0.396555  0.341017  0.230737  0.158237
# ...    ...       ...       ...       ...       ...       ...       ...
# 1077  1077   EPFAILM  0.159330 -0.273244  0.321571  0.135086  0.110988
# 1078  1078    FDPVQI  0.112392 -0.322473  0.400531  0.066830  0.017764
# 1081  1081        CT  0.103353 -0.145116  0.188701  0.289863 -0.004856
# 1082  1082  GIDNEPLT  0.196097 -0.228900  0.340516  0.048953  0.070061
# 1083  1083      AQSD  0.095687 -0.199922  0.253466 -0.108810 -0.053769
#
#              5         6         7  ...       311       312       313  \
# 5    -0.073738 -0.178867 -0.135293  ... -0.034402  0.177149 -0.002433
# 9     0.025865 -0.244675  0.006076  ... -0.156657  0.058971 -0.006924
# 10   -0.148579 -0.110689 -0.017494  ... -0.044912  0.171468 -0.001797
# 11   -0.151916 -0.084755 -0.003137  ... -0.014979  0.201637  0.045172
# 12   -0.145218 -0.123913 -0.002735  ...  0.054522  0.109205 -0.020831
# ...        ...       ...       ...  ...       ...       ...       ...
# 1077 -0.069941 -0.079460 -0.069443  ...  0.027065  0.143293  0.030217
# 1078 -0.051153 -0.088410 -0.081356  ... -0.079543  0.237188 -0.032832
# 1081 -0.154000 -0.359408 -0.301271  ...  0.049362  0.350288 -0.014774
# 1082 -0.124927 -0.078908 -0.030626  ...  0.095428  0.128027 -0.051088
# 1083  0.106536 -0.160762 -0.078627  ...  0.046013  0.372309 -0.117916
#
#            314       315       316       317       318       319  label
# 5    -0.087986  0.075938  0.097232  0.155471  0.374548  0.065724      1
# 9     0.039511 -0.012344  0.129600  0.091925  0.000396 -0.233784      1
# 10    0.069665  0.102730  0.118630 -0.041048  0.300907  0.014544      1
# 11    0.041134  0.150533  0.140848 -0.055020  0.268257  0.065306      1
# 12    0.084542  0.139587  0.200506 -0.057230  0.256894  0.060221      1
# ...        ...       ...       ...       ...       ...       ...    ...
# 1077  0.054226  0.149324  0.167510 -0.020403  0.261917  0.123162      0
# 1078  0.072031  0.108638  0.127356  0.008038  0.261568  0.057661      0
# 1081 -0.005616 -0.005052  0.055868  0.054323  0.300959 -0.028081      0
# 1082  0.130596  0.051913  0.042928  0.001201  0.160545 -0.022739      0
# 1083 -0.061262 -0.153536 -0.041605  0.226042  0.125093 -0.141946      0
#
# [877 rows x 323 columns]
